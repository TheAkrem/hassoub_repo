# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_path = '/content/drive/MyDrive/Computer_vision/OpenCV/Naruto Eyes.jpeg'

# %%
img = cv2.imread(image_path)

# %%
img.shape
# Out:
# (250, 202, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
# Out:
# (250, 202)

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
from google.colab.patches import cv2_imshow

# %%
# Load the eye cascade classifier
eye_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# Detect eyes in the grayscale image
eyes = eye_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Draw rectangles around the detected eyes
for (ex, ey, ew, eh) in eyes:
    cv2.rectangle(img, (ex, ey), (ex + ew, ey + eh), (255, 0, 0), 4)

# Display the image with detected faces and eyes
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=202x250>
