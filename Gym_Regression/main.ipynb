# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('vvvv.csv')
df
# Out:
#       Day  Weight_kg
# 0       1        5.0
# 1       2        5.0
# 2       3        5.0
# 3       4        5.0
# 4       5        5.0
# ..    ...        ...
# 995   996       60.0
# 996   997       60.0
# 997   998       60.0
# 998   999       60.0
# 999  1000       60.0
#
# [1000 rows x 2 columns]

# %%
X = df[['Day']]

# %%
Y = df['Weight_kg']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train.values, Y_train)
# Out:
# LinearRegression()

# %%
b0 = round(model.intercept_,2)
b1 = round(model.coef_[0],2)

print('Intercept (b0):', b0)
print('Coefficient (b1):', b1)
# Out:
# Intercept (b0): 20.77
# Coefficient (b1): 0.04

# %%
Tv_advertisment = [[1200]]

pred = model.predict(Tv_advertisment)
print("prediction= ", pred[0])
# Out:
# prediction=  74.7539961808213

# %%
Y_pred = model.predict(X_test.values)

# %%
Y_pred
# Out:
# array([65.48664061, 59.45836077, 34.22056234, 45.6922889 , 51.04576129,
#        64.49692302, 22.02904118, 31.20642242, 34.58045965, 52.57532484,
#        43.12802061, 45.91722472, 56.08432355, 31.56631973, 46.81696797,
#        23.28868174, 61.57275743, 28.6871413 , 21.44420806, 24.27839933,
#        22.20898983, 42.45321317, 34.7604083 , 34.80539546, 60.53805268,
#        56.2642722 , 22.83881011, 25.44806556, 55.00463164, 20.85937494,
#        57.8388229 , 52.75527349, 48.43650584, 56.35424653, 39.16915027,
#        53.92493972, 63.86710274, 37.27968942, 62.11260339, 32.82596029,
#        31.16143526, 65.6216021 , 49.38123626, 52.21542753, 32.10616568,
#        56.03933638, 57.65887425, 27.15757776, 35.03033128, 47.22185244,
#        35.70513872, 34.08560085, 32.60102448, 40.24884218, 59.59332226,
#        46.99691663, 33.05089611, 32.96092178, 65.21671763, 35.16529277,
#        46.41208351, 49.74113357, 27.20256492, 29.9017947 , 39.39408608,
#        29.63187172, 32.6909988 , 44.70257132, 32.15115285, 46.72699365,
#        54.01491405, 34.26554951, 54.10488838, 31.92621703, 62.47250069,
#        39.34909892, 38.31439417, 56.6241695 , 47.85167272, 50.23599236,
#        32.55603731, 41.32853409, 38.17943268, 64.99178182, 61.70771892,
#        51.99049172, 31.43135824, 43.35295643, 43.17300777, 60.13316821,
#        41.14858544, 43.03804629, 62.3375392 , 33.36580625, 49.51619775,
#        42.63316182, 46.36709635, 25.67300138, 37.32467659, 49.78612073,
#        56.12931071, 60.08818105, 23.73855337, 61.39280878, 35.07531844,
#        49.42622343, 50.77583832, 56.30925936, 63.9120899 , 30.44164065,
#        25.17814259, 47.04190379, 41.77840572, 44.34267401, 32.28611433,
#        38.13444552, 45.3323916 , 37.99948403, 42.81311047, 43.89280238,
#        55.9043749 , 61.4827831 , 26.30282166, 63.37224395, 23.51361756,
#        58.78355333, 37.5496124 , 33.5457549 , 63.05733381, 48.16658286,
#        43.08303345, 49.15630045, 47.62673691, 52.89023498, 54.6897215 ,
#        48.88637747, 34.85038262, 21.17428508, 44.61259699, 60.22314254,
#        25.35809124, 48.481493  , 44.20771252, 32.01619136, 33.32081908,
#        39.88894488, 38.08945836, 38.58431715, 23.24369458, 22.34395132,
#        33.00590894, 22.16400267, 38.94421445, 54.86967015, 64.67687167,
#        65.35167912, 41.37352126, 37.09974077, 59.50334793, 42.54318749,
#        46.9069423 , 65.17173047, 51.7655559 , 59.68329659, 62.51748785,
#        37.81953538, 35.21027993, 63.1922953 , 36.60488198, 39.6190219 ,
#        63.32725679, 56.57918234, 27.33752641, 57.97378439, 42.94807196,
#        54.59974717, 31.61130689, 49.96606938, 60.67301417, 27.29253924,
#        55.31954178, 65.75656359, 41.82339289, 34.98534411, 65.30669196,
#        62.29255204, 53.07018363, 41.41850842, 55.58946475, 29.99176902,
#        58.3336817 , 58.24370737, 40.38380367, 21.03932359, 55.4095161 ,
#        51.36067144, 53.29511944, 30.48662782, 50.1910052 , 27.56246222])

# %%
from sklearn import metrics
import numpy as np

mae = metrics.mean_absolute_error(Y_test,Y_pred)
mse = metrics.mean_squared_error(Y_test,Y_pred)
rmse = np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))

# %%
print('mae =',mae.round(2))
print('mse =',mse.round(2))
print('rmse =',rmse.round(2))
# Out:
# mae = 2.81
# mse = 13.97
# rmse = 3.74

# %%
sns.regplot(x = Y_test, y = Y_pred)
# Out:
# <Axes: xlabel='Weight_kg'>
